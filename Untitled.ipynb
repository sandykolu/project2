# %%
import pandas as pd
import os, glob
import json
path = "."
all_files = glob.glob(os.path.join(path, "cali_*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged   = pd.concat(df_from_each_file, ignore_index=True)
df_merged.to_csv( "merged.csv")
df_merged = df_merged.iloc[:,2:]
df_merged['year'] = pd.DatetimeIndex(df_merged['Date']).year
df_merged['month'] = pd.DatetimeIndex(df_merged['Date']).month
df = df_merged.set_index("Name")






df['Location'] = df[['Lat', 'Lon']].apply(tuple, axis=1)
df
# a_dictionary = new_df.to_dict("list")
# a_dictionary

print(json.dumps(json.loads(df.reset_index().to_json(orient='records')), indent=2))

import sys

print('This message will be displayed on the screen.')

with open('filename.txt', 'w') as f:
    print(json.dumps(json.loads(df.reset_index().to_json(orient='records')), indent=2), file=f)
#     print('This message will be written to a file.', file=f)
# Out:
# [
#   {
#     "Name": "241 Fire",
#     "Lat": 33.7626,
#     "Lon": -117.7274,
#     "Date": "2015-07-13",
#     "year": 2015,
#     "month": 7,
#     "Location": [
#       33.7626,
#       -117.7274
#     ]
#   },
#   {
#     "Name": "3-11 Fire",
#     "Lat": 41.29226,
#     "Lon": -121.172117,
#     "Date": "2015-07-23",
#     "year": 2015,
#     "month": 7,
#     "Location": [
#       41.29226,
#       -121.172117
#     ]
#   },
#   {
#     "Name": "3-12 Fire",
#     "Lat": 40.856422,
#     "Lon": -121.101623,
#     "Date": "2015-07-23",
#     "year": 2015,
#     "month": 7,
#     "Location": [
#       40.856422,
#       -121.101623
#     ]
#   },
#   {
#     "Name": "36 Fire",
#     "Lat": 40.3506868,
#     "Lon": -121.7786799,
#     "Date": "2015-08-08",
#     "year": 2015,
#     "month": 8,
#     "Location": [
#       40.3506868,
#       -121.7786799
#     ]
#   },
#   {
#     "Name": "Advance Fire",
#     "Lat": 36.49845,
#     "Lon": -118.9009,
#     "Date": "2015-07-30",
# ...

# %%
import pandas as pd
import json
data = pd.read_csv("cali_2013_fire_points.csv")
data[0:]

# %%
data

# %%
data["r"][0][1]

# %%
df = data["r"][0]
df
coordinates = []
for data in df:
    coordinates = data[]
# new_df = pd.DataFrame(df)
# new_df

# %%
def df_to_geojson(df_final, properties, lat='lat', lon='lon'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df_final.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = ['Team Name', 'Team City', 'lat','lon']
geojson = df_to_geojson(df_final, cols)
